# %% [markdown]
# # Dicionários
#
# ## Aula 8.3

# %% [markdown]
# ### Q1.
#
# Escreva uma função em Python chamada ```contagem_caracteres``` que recebe uma string como parâmetro e retorna um dicionário onde as chaves são os caracteres presentes na string e os valores são a contagem de cada caractere.

# %%
# Implemente aqui a função contagem_caracteres
def contagem_caracteres(texto):
    contagem = {}
    for caractere in texto:
        if caractere in texto:
            contagem[caractere] += 1
        else:
            contagem[caractere] = 1
            return contagem

# %%
# Exemplo de uso:
frase = "python programming"
resultado = contagem_caracteres(frase)
print(resultado)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Exemplo de uso:
#       2 frase = "python programming"
# ----> 3 resultado = contagem_caracteres(frase)
#       4 print(resultado)
#
# Cell In[3], line 6, in contagem_caracteres(texto)
#       4 for caractere in texto:
#       5     if caractere in texto:
# ----> 6         contagem[caractere] += 1
#       7     else:
#       8         contagem[caractere] = 1
#
# KeyError: 'p'

# %% [markdown]
# ### Q2.
#
# Baixe o arquivo contendo o roteiro do filme brasileiro "Estômago" e salve em seu computador com o nome "estomago.txt".
#
# https://aplauso.imprensaoficial.com.br/edicoes/12.0.813.502/12.0.813.502.txt
#
# - Escreva um script python que abre o arquivo de texto e cria um dicionário contando a quantidade de vezes que cada palavra aparece no texto.
# - Em seguida ordene o dicionário de forma decrescente pelos valores. Dessa maneira ele irá apresentar as palavras mais frequentes no início.
# - Apresente na tela o dicionário ordenado

# %%
fp = open ('estomago.txt', 'r')
linhas = [linhas.split('') for linha in fp.readlines()]
print (linhas[0])
fp. close ()
dict_contador = ()
for linha in linhas:
    for palavra in linha:
       palavra = palavra.lower
       dict_contador[palavra] = dict_contador.get(palavra, 0) + 1
sorted(dict_contador.items())
key = lambda item: item [1],
reverse = True

# %% [markdown]
# ### Q3.
#
# Crie uma função chamada ```mesclar_dicionarios``` que recebe dois dicionários como parâmetros e retorna um novo dicionário contendo a fusão dos dois. Se houver chaves comuns, o maior valor deve prevalecer.

# %%
# Implemente aqui a função mesclar_dicionarios
def mesclar_dicionarios (d1, d2):
    d3 = d1.copy()
    for chave, valor in d2.items():
        if chave in d3:
            d3[chave] = max(d3[chave], valor)
        else:
            d3[chave] = valor
    return d3

# %%
# Exemplo de uso:
dicionario1 = {'a': 1, 'b': 2, 'c': 3}
dicionario2 = {'b': 4, 'd': 5}
resultado = mesclar_dicionarios(dicionario1, dicionario2)
print(resultado)
# Saída esperada: {'a': 1, 'b': 4, 'c': 3, 'd': 5}
# Out:
# {'a': 1, 'b': 4, 'c': 3, 'd': 5}

# %% [markdown]
# ### Q4.
#
# Desenvolva uma função em Python chamada ```filtrar_dicionario``` que recebe um dicionário e uma lista de chaves como parâmetros e retorna um novo dicionário contendo apenas as chaves que estão presentes na lista.

# %%
# Implemente aqui a função filtrar_dicionario
def filtrar_dicionario(dicionario, lista_chaves):
    novo_dicionario = {}
    for chave in lista_chaves:
        if chave in dicionario:
            novo_dicionario[chave] = dicionario[chave]
    return novo_dicionario
# Out:
#   Cell In[16], line 2
#     def filtrar_dicionario(dicionario, lista_chaves)
#                                                     ^
# SyntaxError: expected ':'

# %%
# Exemplo de uso:
dados = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
chaves_filtradas = ['a', 'c', 'e']
resultado = filtrar_dicionario(dados, chaves_filtradas)
print(resultado)
# Saída esperada: {'a': 1, 'c': 3, 'e': 5}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       2 dados = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
#       3 chaves_filtradas = ['a', 'c', 'e']
# ----> 4 resultado = filtrar_dicionario(dados, chaves_filtradas)
#       5 print(resultado)
#       6 # Saída esperada: {'a': 1, 'c': 3, 'e': 5}
#
# Cell In[13], line 4, in filtrar_dicionario(dados, chaves_filtradas)
#       2 def filtrar_dicionario(dados, chaves_filtradas):
#       3     novo_dicionario = []
# ----> 4     for chave in lista_chaves:
#       5         if chave in dicionario:
#       6             novo_dicionario[chave] = dicionario[chave]
#
# NameError: name 'lista_chaves' is not defined

# %% [markdown]
# ### Q5.
#
# Você está responsável por analisar os resultados de uma votação. Cada voto é representado por um dicionário com o nome do candidato e a quantidade de votos que recebeu em uma determinada sessão eleitoral. Escreva uma função chamada ```resultado_votacao``` que recebe uma lista de dicionários de votos e retorna um dicionário onde as chaves são os nomes dos candidatos, e os valores são tuplas ```(total, percentual)``` com o total de votos recebidos por cada candidato e o percentual em relação à soma total de votos em todos os candidatos.

# %%
# Implemente aqui a função resultado_votacao
def resultado_votacao(votos):
    totais = {}
    for item in votos:
        for nome, qtd in item.items():
            if nome in totais:
                totais[nome] += qtd
            else:
                totais[nome] = qtd
    total_geral = sum(totais.values())
    resultado = {}
    for nome, total in totais.items():
        percentual = (total / total_geral) * 100
        resultado[nome] = (total, round(percentual, 2))
    return resultado

# %%
# Exemplo de uso:
votos = [
    {'candidato_A': 120, 'candidato_B': 85, 'candidato_C': 90},
    {'candidato_A': 110, 'candidato_B': 95, 'candidato_C': 80},
    {'candidato_A': 130, 'candidato_B': 78, 'candidato_C': 105},
]
resultado = resultado_votacao(votos)
print(resultado)  # Saída esperada: {'candidato_A': (360, 40.31), 'candidato_B': (258, 28.89), 
                                ###  'candidato_C': (275, 30.79)}
# Out:
# {'candidato_A': (360, 40.31), 'candidato_B': (258, 28.89), 'candidato_C': (275, 30.8)}
